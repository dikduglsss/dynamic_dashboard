# %%
import json

with open('name_table.json') as f:
    config = json.load(f)

table_name = config['table_name']

# %%
import psycopg2

def find_columns(table_name, conn):
    # Ключевые слова для поиска времени и типа события
    event_time_keywords = ['event', 'time', 'timestamp', 'date']
    event_type_keywords = ['event', 'type', 'category', 'action']

    def column_score(column_name, data_type, keywords, target_types):
        score = 0
        column_name_lower = column_name.lower()

        # Увеличиваем вес для точных ключевых слов
        for keyword in keywords:
            if keyword in column_name_lower:
                score += 2
            if column_name_lower.startswith(keyword) or column_name_lower.endswith(keyword):
                score += 1

        # Увеличиваем вес, если тип данных совпадает с целевым
        if data_type in target_types:
            score += 3
        return score

    # Подключение и выполнение запроса для получения столбцов таблицы с их типами данных
    with conn.cursor() as cur:
        cur.execute(f"""
            SELECT column_name, data_type 
            FROM information_schema.columns 
            WHERE table_name = %s
        """, (table_name,))
        
        columns = cur.fetchall()

    # Поиск столбца для времени события
    event_time_column = max(
        columns, 
        key=lambda col: column_score(col[0], col[1], event_time_keywords, ['Timestamp', 'time'])
    )

    # Поиск столбца для типа события
    event_type_column = max(
        columns, 
        key=lambda col: column_score(col[0], col[1], event_type_keywords, ['text'])
    )

    return event_time_column[0], event_type_column[0]

# Пример подключения к базе данных
conn = psycopg2.connect(
    user="postgres",
    password="1",
    host="localhost",
    port="5435",
    database="postgres"
)

# Название таблицы
table_name = "anti_frod"

# Поиск столбцов
event_time_column, event_type_column = find_columns(table_name, conn)
print(f"Event Time Column: {event_time_column}")
print(f"Event Type Column: {event_type_column}")

# Закрытие соединения
conn.close()
# Out:
# Event Time Column: event_time
# Event Type Column: event_type

# %%
import psycopg2
import pandas as pd

# Настройка соединения с базой данных PostgreSQL
conn = psycopg2.connect(
    user="postgres",
    password="1",
    host="localhost",
    port="5435",
    database="postgres"
)

# Название таблицы
table_name = "anti_frod"

# Используем pandas для загрузки данных в DataFrame
df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)

# Закрываем соединение
conn.close()
# Out:
# C:\Users\idukh\AppData\Local\Temp\ipykernel_26660\1802237097.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)

# %%
df
# Out:
#      atm_acquiring_country atm_acquiring_icc atm_branch atm_card_entry_mode  \
# 0                       UK          ICC_9910   Branch_1         CONTACTLESS
# 1                   Russia          ICC_8912   Branch_5                CHIP
# 2                   France          ICC_6210  Branch_30     MAGNETIC_STRIPE
# 3                   France          ICC_7086  Branch_47                CHIP
# 4                   Russia          ICC_2583  Branch_19                CHIP
# ...                    ...               ...        ...                 ...
# 2995                   USA          ICC_2058  Branch_33         CONTACTLESS
# 2996                    UK          ICC_2398   Branch_2     MAGNETIC_STRIPE
# 2997               Germany          ICC_6302  Branch_38         CONTACTLESS
# 2998                   USA          ICC_7852  Branch_14         CONTACTLESS
# 2999               Germany          ICC_6951  Branch_33     MAGNETIC_STRIPE
#
#       atm_cardless  atm_cash_in  atm_cash_in_acc  atm_cash_in_pay  \
# 0             True         True             True             True
# 1            False        False             True             True
# 2             True        False             True            False
# 3             True         True             True            False
# 4             True        False            False             True
# ...            ...          ...              ...              ...
# 2995          True        False             True            False
# 2996         False         True            False            False
# 2997          True         True             True            False
# 2998          True        False             True             True
# 2999          True         True             True             True
#
#               atm_city atm_class  ... user_doc_number   user_doc_type  \
# 0           Manchester       VIP  ...        DOC_1437  Driver License
# 1               Moscow  Standard  ...        DOC_3699         ID Card
# 2                 Lyon       VIP  ...        DOC_7611         ID Card
# 3            Marseille   Premium  ...        DOC_6834  Driver License
# 4     Saint Petersburg       VIP  ...        DOC_8760  Driver License
# ...                ...       ...  ...             ...             ...
# 2995           Chicago   Premium  ...        DOC_1547         ID Card
# 2996        Birmingham  Standard  ...        DOC_7672  Driver License
# 2997            Munich  Standard  ...        DOC_4195         ID Card
# 2998          New York  Standard  ...        DOC_4949        Passport
# 2999            Berlin   Premium  ...        DOC_6337  Driver License
#
#      user_first_name    user_id user_last_name    user_name user_patronymic  \
# 0        FirstName_6  USER_5745    LastName_28  UserName_11   Patronymic_54
# 1       FirstName_37  USER_1090    LastName_74  UserName_87   Patronymic_67
# 2       FirstName_50  USER_5791    LastName_46  UserName_50   Patronymic_68
# 3       FirstName_56  USER_3766     LastName_1  UserName_48   Patronymic_52
# 4        FirstName_1  USER_9514    LastName_86   UserName_6   Patronymic_63
# ...              ...        ...            ...          ...             ...
# 2995    FirstName_32  USER_5363    LastName_82  UserName_80   Patronymic_59
# 2996    FirstName_20  USER_7703     LastName_7  UserName_90   Patronymic_54
# 2997    FirstName_97  USER_2438    LastName_34  UserName_60    Patronymic_4
# 2998    FirstName_60  USER_4655    LastName_98  UserName_90   Patronymic_51
# 2999    FirstName_21  USER_3353    LastName_91  UserName_33   Patronymic_55
#
#      user_segment user_type usr_ip_cur_add
# 0            Gold     Admin       10.0.0.1
# 1            Gold     Admin    192.168.1.1
# 2          Bronze     Guest       10.0.0.1
# 3            Gold     Admin    192.168.1.1
# 4            Gold      User     172.16.0.1
# ...           ...       ...            ...
# 2995         Gold     Admin     172.16.0.1
# 2996       Silver      User    192.168.1.1
# 2997         Gold     Guest       10.0.0.1
# 2998         Gold     Guest       10.0.0.1
# 2999       Silver      User    192.168.1.1
#
# [3000 rows x 191 columns]

# %% [markdown]
# Time_1

# %%
final_query_time_1 = f"SELECT \"{event_time_column}\", \"{event_type_column}\" \n   FROM {table_name} "

# %%
Time_1 = (
"table_name: Time_1",
"main_dttm_col: event_time",
"description: null",
"default_endpoint: null",
"offset: 0",
"cache_timeout: null",
"catalog: postgres",
"schema: public",
f"sql: {(final_query_time_1)} ",
"params: null",
"template_params: null",
"filter_select_enabled: true",
"fetch_values_predicate: null",
"extra: null",
"normalize_columns: false",
"always_filter_main_dttm: false",
"uuid: 619ac62e-8715-4084-823e-0cb2e520755e",
"metrics:",
"- metric_name: count",
"  verbose_name: COUNT(*)",
"  metric_type: count",
"  expression: COUNT(*)",
"  description: null",
"  d3format: null",
"  currency: null",
"  extra: null",
"  warning_text: null",
"columns:",
"- column_name: event_time",
"  verbose_name: null",
"  is_dttm: true",
"  is_active: true",
"  type: DATETIME",
"  advanced_data_type: null",
"  groupby: true",
"  filterable: true",
"  expression: null",
"  description: null",
"  python_date_format: null",
"  extra: null",
"- column_name: event_type",
"  verbose_name: null",
"  is_dttm: false",
"  is_active: true",
"  type: STRING",
"  advanced_data_type: null",
"  groupby: true",
"  filterable: true",
"  expression: null",
"  description: null",
"  python_date_format: null",
"  extra: null",
"version: 1.0.0",
"database_uuid: 2f651e35-38e7-4b9b-a47e-87996c769118"
)

# %% [markdown]
# Time_2

# %%
import sqlite3

columns =  df.columns.tolist()

count_parts = [f"COUNT('{column}')" for column in columns]

final_query_time_2 =  (
    "SELECT \r\n"
    "    GREATEST(\r\n"
    "        " + ',\r\n        '.join(count_parts) + "\r\n"
    "    ) AS count_line\r\n"
    "   FROM \r\n"
    f"    {table_name}\r\n"
    "   WHERE \r\n"
    "    " + ' OR '.join([f"'{column}' IS NOT NULL" for column in columns]) + ";"
)

print(final_query_time_2)

conn.close()
# Out:
# SELECT
#     GREATEST(
#         COUNT('atm_acquiring_country'),
#         COUNT('atm_acquiring_icc'),
#         COUNT('atm_branch'),
#         COUNT('atm_card_entry_mode'),
#         COUNT('atm_cardless'),
#         COUNT('atm_cash_in'),
#         COUNT('atm_cash_in_acc'),
#         COUNT('atm_cash_in_pay'),
#         COUNT('atm_city'),
#         COUNT('atm_class'),
#         COUNT('atm_continent'),
#         COUNT('atm_country'),
#         COUNT('atm_cvv_check'),
#         COUNT('atm_exchange'),
#         COUNT('atm_forwarding_icc'),
#         COUNT('atm_is_fi_owner'),
#         COUNT('atm_merchant_id'),
#         COUNT('atm_merchant_name'),
#         COUNT('atm_owner_fi_name'),
#         COUNT('atm_pin_check'),
#         COUNT('atm_pin_entry_mode'),
#         COUNT('atm_receiving_icc'),
#         COUNT('atm_region'),
#         COUNT('atm_retailer_name'),
#         COUNT('atm_usr_num_hit'),
#         COUNT('atm_virt'),
#         COUNT('atm_zip'),
#         COUNT('branch_branch'),
#         COUNT('branch_host'),
#         COUNT('branch_office'),
#         COUNT('branch_operator_id'),
#         COUNT('branch_tercode'),
#         COUNT('card_balance'),
#         COUNT('card_balance_currency'),
#         COUNT('card_bin'),
#         COUNT('card_category'),
#         COUNT('card_contract_currency'),
#         COUNT('card_day_limit'),
#         COUNT('card_day_limit_currency'),
#         COUNT('card_days_since_issue'),
#         COUNT('card_expire_date'),
#         COUNT('card_issue_date'),
#         COUNT('card_issuer_country'),
#         COUNT('card_issuer_id'),
#         COUNT('card_number'),
#         COUNT('card_product'),
#         COUNT('card_system'),
#         COUNT('card_type'),
#         COUNT('cardholder_amount'),
#         COUNT('cardholder_currency'),
#         COUNT('channel'),
#         COUNT('client_trx_id'),
#         COUNT('conv_rate'),
#         COUNT('device_tz'),
#         COUNT('devi_src_mob_har'),
#         COUNT('devi_src_mob_osid'),
#         COUNT('ec_card_validarion_res'),
#         COUNT('ec_cvv2_data'),
#         COUNT('event_time'),
#         COUNT('event_type'),
#         COUNT('evt_act'),
#         COUNT('ext_amount_rub'),
#         COUNT('ext_branch_region'),
#         COUNT('ext_device_hash'),
#         COUNT('ext_evt_des'),
#         COUNT('ext_issuer_bank_name'),
#         COUNT('ext_mtid'),
#         COUNT('ext_operation_category'),
#         COUNT('ext_operation_id'),
#         COUNT('ext_operation_type'),
#         COUNT('ext_payee_acc'),
#         COUNT('ext_payee_bic'),
#         COUNT('ext_payee_card_num'),
#         COUNT('ext_payee_inn'),
#         COUNT('ext_user_phone'),
#         COUNT('ext_payer_inn'),
#         COUNT('ext_resp_code'),
#         COUNT('ext_user_bic'),
#         COUNT('ext_user_inn'),
#         COUNT('ext_usr_log'),
#         COUNT('ext_usr_tax'),
#         COUNT('fraud_type'),
#         COUNT('fraud_type_aml'),
#         COUNT('geoip_city'),
#         COUNT('geoip_country'),
#         COUNT('geoip_provider'),
#         COUNT('geoip_region'),
#         COUNT('ip_classa'),
#         COUNT('ip_classb'),
#         COUNT('ip_classc'),
#         COUNT('int_web_devi_key'),
#         COUNT('ip_mv_too_fast'),
#         COUNT('mcc'),
#         COUNT('mcc_group'),
#         COUNT('operator_department'),
#         COUNT('operator_name'),
#         COUNT('operator_nubmer'),
#         COUNT('operator_position'),
#         COUNT('org_id'),
#         COUNT('payee_account_type'),
#         COUNT('payee_amount'),
#         COUNT('payee_bank_type'),
#         COUNT('payee_bic'),
#         COUNT('payee_currency'),
#         COUNT('payee_name'),
#         COUNT('payee_ownership'),
#         COUNT('payee_rate'),
#         COUNT('payee_user_id'),
#         COUNT('payer_bic'),
#         COUNT('payer_name'),
#         COUNT('policy_action'),
#         COUNT('policy_action_aml'),
#         COUNT('policy_action_fr'),
#         COUNT('policy_rule_id'),
#         COUNT('policy_rule_id_aml'),
#         COUNT('policy_rule_id_fr'),
#         COUNT('policy_rule_name'),
#         COUNT('policy_rule_num_aml'),
#         COUNT('policy_rule_num_fr'),
#         COUNT('pos_active_state'),
#         COUNT('pos_auth_cap'),
#         COUNT('pos_auth_entity'),
#         COUNT('pos_auth_method'),
#         COUNT('pos_capture_cap'),
#         COUNT('pos_card_presence'),
#         COUNT('pos_cardholder_presence'),
#         COUNT('pos_data_input_cap'),
#         COUNT('pos_data_input_mode'),
#         COUNT('pos_data_out_cap'),
#         COUNT('pos_final_scoring'),
#         COUNT('pos_merchant_scoring'),
#         COUNT('pos_op_env'),
#         COUNT('pos_partial_approval'),
#         COUNT('pos_pin_cap_cap'),
#         COUNT('pos_pin_service_code'),
#         COUNT('pos_pin_service_result'),
#         COUNT('pos_purchase_amt_only'),
#         COUNT('pos_real_time_subst'),
#         COUNT('pos_term_out_cap'),
#         COUNT('pos_type'),
#         COUNT('repl_amount'),
#         COUNT('resolution'),
#         COUNT('resolution_aml'),
#         COUNT('resolution_date'),
#         COUNT('resolution_date_aml'),
#         COUNT('risk_score_aml_final'),
#         COUNT('risk_score_final'),
#         COUNT('risk_score_payee_final'),
#         COUNT('ter_code'),
#         COUNT('tra_cln_def'),
#         COUNT('tra_cln_typ'),
#         COUNT('tra_tra_amo_amo'),
#         COUNT('tra_tra_amo_cur'),
#         COUNT('tra_tra_oth_id'),
#         COUNT('tra_tra_own_id'),
#         COUNT('trx_atm_id'),
#         COUNT('trx_terminal_id'),
#         COUNT('u_atm_day_f_hit'),
#         COUNT('u_atm_day_l_hit'),
#         COUNT('u_day_sin_ema_cha'),
#         COUNT('u_day_sin_f_hit'),
#         COUNT('u_day_sin_pwd_cha'),
#         COUNT('u_day_sin_tel_cha'),
#         COUNT('u_devprn_day_f_hit'),
#         COUNT('u_hour_sin_f_hit'),
#         COUNT('u_ip_day_sin_f_hit'),
#         COUNT('u_ip_diff_from_p'),
#         COUNT('u_ipb_day_sin_f_hit'),
#         COUNT('u_ipc_day_sin_f_hit'),
#         COUNT('u_isp_day_sin_f_hit'),
#         COUNT('u_mobdev_day_sin_f_hit'),
#         COUNT('u_mobdev_day_sin_l_hit'),
#         COUNT('u_mobisp_day_sin_f_hit'),
#         COUNT('u_mobmac_day_sin_f_hit'),
#         COUNT('u_p_day_sin_f_hit'),
#         COUNT('u_sim_day_sin_f_hit'),
#         COUNT('u_webdev_day_sin_f_hit'),
#         COUNT('u_webdev_day_sin_l_hit'),
#         COUNT('unified_id'),
#         COUNT('user_birthdate'),
#         COUNT('user_category'),
#         COUNT('user_doc_number'),
#         COUNT('user_doc_type'),
#         COUNT('user_first_name'),
#         COUNT('user_id'),
#         COUNT('user_last_name'),
#         COUNT('user_name'),
#         COUNT('user_patronymic'),
#         COUNT('user_segment'),
#         COUNT('user_type'),
#         COUNT('usr_ip_cur_add')
#     ) AS count_line
#    FROM
#     anti_frod
#    WHERE
#     'atm_acquiring_country' IS NOT NULL OR 'atm_acquiring_icc' IS NOT NULL OR 'atm_branch' IS NOT NULL OR 'atm_card_entry_mode' IS NOT NULL OR 'atm_cardless' IS NOT NULL OR 'atm_cash_in' IS NOT NULL OR 'atm_cash_in_acc' IS NOT NULL OR 'atm_cash_in_pay' IS NOT NULL OR 'atm_city' IS NOT NULL OR 'atm_class' IS NOT NULL OR 'atm_continent' IS NOT NULL OR 'atm_country' IS NOT NULL OR 'atm_cvv_check' IS NOT NULL OR 'atm_exchange' IS NOT NULL OR 'atm_forwarding_icc' IS NOT NULL OR 'atm_is_fi_owner' IS NOT NULL OR 'atm_merchant_id' IS NOT NULL OR 'atm_merchant_name' IS NOT NULL OR 'atm_owner_fi_name' IS NOT NULL OR 'atm_pin_check' IS NOT NULL OR 'atm_pin_entry_mode' IS NOT NULL OR 'atm_receiving_icc' IS NOT NULL OR 'atm_region' IS NOT NULL OR 'atm_retailer_name' IS NOT NULL OR 'atm_usr_num_hit' IS NOT NULL OR 'atm_virt' IS NOT NULL OR 'atm_zip' IS NOT NULL OR 'branch_branch' IS NOT NULL OR 'branch_host' IS NOT NULL OR 'branch_office' IS NOT NULL OR 'branch_operator_id' IS NOT NULL OR 'branch_tercode' IS NOT NULL OR 'card_balance' IS NOT NULL OR 'card_balance_currency' IS NOT NULL OR 'card_bin' IS NOT NULL OR 'card_category' IS NOT NULL OR 'card_contract_currency' IS NOT NULL OR 'card_day_limit' IS NOT NULL OR 'card_day_limit_currency' IS NOT NULL OR 'card_days_since_issue' IS NOT NULL OR 'card_expire_date' IS NOT NULL OR 'card_issue_date' IS NOT NULL OR 'card_issuer_country' IS NOT NULL OR 'card_issuer_id' IS NOT NULL OR 'card_number' IS NOT NULL OR 'card_product' IS NOT NULL OR 'card_system' IS NOT NULL OR 'card_type' IS NOT NULL OR 'cardholder_amount' IS NOT NULL OR 'cardholder_currency' IS NOT NULL OR 'channel' IS NOT NULL OR 'client_trx_id' IS NOT NULL OR 'conv_rate' IS NOT NULL OR 'device_tz' IS NOT NULL OR 'devi_src_mob_har' IS NOT NULL OR 'devi_src_mob_osid' IS NOT NULL OR 'ec_card_validarion_res' IS NOT NULL OR 'ec_cvv2_data' IS NOT NULL OR 'event_time' IS NOT NULL OR 'event_type' IS NOT NULL OR 'evt_act' IS NOT NULL OR 'ext_amount_rub' IS NOT NULL OR 'ext_branch_region' IS NOT NULL OR 'ext_device_hash' IS NOT NULL OR 'ext_evt_des' IS NOT NULL OR 'ext_issuer_bank_name' IS NOT NULL OR 'ext_mtid' IS NOT NULL OR 'ext_operation_category' IS NOT NULL OR 'ext_operation_id' IS NOT NULL OR 'ext_operation_type' IS NOT NULL OR 'ext_payee_acc' IS NOT NULL OR 'ext_payee_bic' IS NOT NULL OR 'ext_payee_card_num' IS NOT NULL OR 'ext_payee_inn' IS NOT NULL OR 'ext_user_phone' IS NOT NULL OR 'ext_payer_inn' IS NOT NULL OR 'ext_resp_code' IS NOT NULL OR 'ext_user_bic' IS NOT NULL OR 'ext_user_inn' IS NOT NULL OR 'ext_usr_log' IS NOT NULL OR 'ext_usr_tax' IS NOT NULL OR 'fraud_type' IS NOT NULL OR 'fraud_type_aml' IS NOT NULL OR 'geoip_city' IS NOT NULL OR 'geoip_country' IS NOT NULL OR 'geoip_provider' IS NOT NULL OR 'geoip_region' IS NOT NULL OR 'ip_classa' IS NOT NULL OR 'ip_classb' IS NOT NULL OR 'ip_classc' IS NOT NULL OR 'int_web_devi_key' IS NOT NULL OR 'ip_mv_too_fast' IS NOT NULL OR 'mcc' IS NOT NULL OR 'mcc_group' IS NOT NULL OR 'operator_department' IS NOT NULL OR 'operator_name' IS NOT NULL OR 'operator_nubmer' IS NOT NULL OR 'operator_position' IS NOT NULL OR 'org_id' IS NOT NULL OR 'payee_account_type' IS NOT NULL OR 'payee_amount' IS NOT NULL OR 'payee_bank_type' IS NOT NULL OR 'payee_bic' IS NOT NULL OR 'payee_currency' IS NOT NULL OR 'payee_name' IS NOT NULL OR 'payee_ownership' IS NOT NULL OR 'payee_rate' IS NOT NULL OR 'payee_user_id' IS NOT NULL OR 'payer_bic' IS NOT NULL OR 'payer_name' IS NOT NULL OR 'policy_action' IS NOT NULL OR 'policy_action_aml' IS NOT NULL OR 'policy_action_fr' IS NOT NULL OR 'policy_rule_id' IS NOT NULL OR 'policy_rule_id_aml' IS NOT NULL OR 'policy_rule_id_fr' IS NOT NULL OR 'policy_rule_name' IS NOT NULL OR 'policy_rule_num_aml' IS NOT NULL OR 'policy_rule_num_fr' IS NOT NULL OR 'pos_active_state' IS NOT NULL OR 'pos_auth_cap' IS NOT NULL OR 'pos_auth_entity' IS NOT NULL OR 'pos_auth_method' IS NOT NULL OR 'pos_capture_cap' IS NOT NULL OR 'pos_card_presence' IS NOT NULL OR 'pos_cardholder_presence'  ...

# %%
Time_2 = (
"table_name: Time_2",
"main_dttm_col: null",
"description: null",
"default_endpoint: null",
"offset: 0",
"cache_timeout: null",
"catalog: postgres",
"schema: public",
f"sql: {repr(final_query_time_2)} ",
"params: null",
"template_params: null",
"filter_select_enabled: true",
"fetch_values_predicate: null",
"extra: null",
"normalize_columns: false",
"always_filter_main_dttm: false",
"uuid: fd91a537-b418-4be5-92ca-c62d01b85d63",
"metrics:",
"- metric_name: count",
"  verbose_name: COUNT(*)",
"  metric_type: count",
"  expression: COUNT(*)",
"  description: null",
"  d3format: null",
"  currency: null",
"  extra: null",
"  warning_text: null",
"columns:",
"- column_name: count_line",
"  verbose_name: null",
"  is_dttm: false",
"  is_active: true",
"  type: LONGINTEGER",
"  advanced_data_type: null",
"  groupby: true",
"  filterable: true",
"  expression: null",
"  description: null",
"  python_date_format: null",
"  extra: null",
"version: 1.0.0",
"database_uuid: 2f651e35-38e7-4b9b-a47e-87996c769118"
)

# %% [markdown]
# Time_3

# %%
text_columns = df.select_dtypes(include=['object']).columns.tolist()

query_parts = []
for column in text_columns:
    query_part = (
        f"  SELECT\r\n"
        f"    '{column}' AS column_name,\r\n"
        f"    COUNT(DISTINCT {column}) AS unique_count\r\n"
        f"  FROM {table_name}"
    )
    query_parts.append(query_part)

final_query_time_3 = "\r\n  UNION ALL\r\n".join(query_parts)

print(final_query_time_3)
# Out:
#   SELECT
#     'atm_acquiring_country' AS column_name,
#     COUNT(DISTINCT atm_acquiring_country) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_acquiring_icc' AS column_name,
#     COUNT(DISTINCT atm_acquiring_icc) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_branch' AS column_name,
#     COUNT(DISTINCT atm_branch) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_card_entry_mode' AS column_name,
#     COUNT(DISTINCT atm_card_entry_mode) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_city' AS column_name,
#     COUNT(DISTINCT atm_city) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_class' AS column_name,
#     COUNT(DISTINCT atm_class) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_continent' AS column_name,
#     COUNT(DISTINCT atm_continent) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_country' AS column_name,
#     COUNT(DISTINCT atm_country) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_cvv_check' AS column_name,
#     COUNT(DISTINCT atm_cvv_check) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_forwarding_icc' AS column_name,
#     COUNT(DISTINCT atm_forwarding_icc) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_is_fi_owner' AS column_name,
#     COUNT(DISTINCT atm_is_fi_owner) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_merchant_id' AS column_name,
#     COUNT(DISTINCT atm_merchant_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_merchant_name' AS column_name,
#     COUNT(DISTINCT atm_merchant_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_owner_fi_name' AS column_name,
#     COUNT(DISTINCT atm_owner_fi_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_pin_check' AS column_name,
#     COUNT(DISTINCT atm_pin_check) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_pin_entry_mode' AS column_name,
#     COUNT(DISTINCT atm_pin_entry_mode) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_receiving_icc' AS column_name,
#     COUNT(DISTINCT atm_receiving_icc) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_region' AS column_name,
#     COUNT(DISTINCT atm_region) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_retailer_name' AS column_name,
#     COUNT(DISTINCT atm_retailer_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'atm_zip' AS column_name,
#     COUNT(DISTINCT atm_zip) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'branch_branch' AS column_name,
#     COUNT(DISTINCT branch_branch) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'branch_host' AS column_name,
#     COUNT(DISTINCT branch_host) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'branch_office' AS column_name,
#     COUNT(DISTINCT branch_office) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'branch_operator_id' AS column_name,
#     COUNT(DISTINCT branch_operator_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'branch_tercode' AS column_name,
#     COUNT(DISTINCT branch_tercode) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_balance_currency' AS column_name,
#     COUNT(DISTINCT card_balance_currency) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_bin' AS column_name,
#     COUNT(DISTINCT card_bin) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_category' AS column_name,
#     COUNT(DISTINCT card_category) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_contract_currency' AS column_name,
#     COUNT(DISTINCT card_contract_currency) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_day_limit_currency' AS column_name,
#     COUNT(DISTINCT card_day_limit_currency) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_days_since_issue' AS column_name,
#     COUNT(DISTINCT card_days_since_issue) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_expire_date' AS column_name,
#     COUNT(DISTINCT card_expire_date) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_issue_date' AS column_name,
#     COUNT(DISTINCT card_issue_date) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_issuer_country' AS column_name,
#     COUNT(DISTINCT card_issuer_country) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_issuer_id' AS column_name,
#     COUNT(DISTINCT card_issuer_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_number' AS column_name,
#     COUNT(DISTINCT card_number) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_product' AS column_name,
#     COUNT(DISTINCT card_product) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_system' AS column_name,
#     COUNT(DISTINCT card_system) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'card_type' AS column_name,
#     COUNT(DISTINCT card_type) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'cardholder_currency' AS column_name,
#     COUNT(DISTINCT cardholder_currency) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'channel' AS column_name,
#     COUNT(DISTINCT channel) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'client_trx_id' AS column_name,
#     COUNT(DISTINCT client_trx_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'device_tz' AS column_name,
#     COUNT(DISTINCT device_tz) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'devi_src_mob_har' AS column_name,
#     COUNT(DISTINCT devi_src_mob_har) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'devi_src_mob_osid' AS column_name,
#     COUNT(DISTINCT devi_src_mob_osid) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ec_card_validarion_res' AS column_name,
#     COUNT(DISTINCT ec_card_validarion_res) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ec_cvv2_data' AS column_name,
#     COUNT(DISTINCT ec_cvv2_data) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'event_type' AS column_name,
#     COUNT(DISTINCT event_type) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'evt_act' AS column_name,
#     COUNT(DISTINCT evt_act) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_branch_region' AS column_name,
#     COUNT(DISTINCT ext_branch_region) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_device_hash' AS column_name,
#     COUNT(DISTINCT ext_device_hash) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_evt_des' AS column_name,
#     COUNT(DISTINCT ext_evt_des) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_issuer_bank_name' AS column_name,
#     COUNT(DISTINCT ext_issuer_bank_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_mtid' AS column_name,
#     COUNT(DISTINCT ext_mtid) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_operation_category' AS column_name,
#     COUNT(DISTINCT ext_operation_category) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_operation_id' AS column_name,
#     COUNT(DISTINCT ext_operation_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_operation_type' AS column_name,
#     COUNT(DISTINCT ext_operation_type) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_payee_acc' AS column_name,
#     COUNT(DISTINCT ext_payee_acc) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_payee_bic' AS column_name,
#     COUNT(DISTINCT ext_payee_bic) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_payee_card_num' AS column_name,
#     COUNT(DISTINCT ext_payee_card_num) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_payee_inn' AS column_name,
#     COUNT(DISTINCT ext_payee_inn) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_user_phone' AS column_name,
#     COUNT(DISTINCT ext_user_phone) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_payer_inn' AS column_name,
#     COUNT(DISTINCT ext_payer_inn) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_resp_code' AS column_name,
#     COUNT(DISTINCT ext_resp_code) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_user_bic' AS column_name,
#     COUNT(DISTINCT ext_user_bic) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_user_inn' AS column_name,
#     COUNT(DISTINCT ext_user_inn) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_usr_log' AS column_name,
#     COUNT(DISTINCT ext_usr_log) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ext_usr_tax' AS column_name,
#     COUNT(DISTINCT ext_usr_tax) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'fraud_type' AS column_name,
#     COUNT(DISTINCT fraud_type) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'fraud_type_aml' AS column_name,
#     COUNT(DISTINCT fraud_type_aml) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'geoip_city' AS column_name,
#     COUNT(DISTINCT geoip_city) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'geoip_country' AS column_name,
#     COUNT(DISTINCT geoip_country) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'geoip_provider' AS column_name,
#     COUNT(DISTINCT geoip_provider) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'geoip_region' AS column_name,
#     COUNT(DISTINCT geoip_region) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ip_classa' AS column_name,
#     COUNT(DISTINCT ip_classa) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ip_classb' AS column_name,
#     COUNT(DISTINCT ip_classb) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ip_classc' AS column_name,
#     COUNT(DISTINCT ip_classc) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'int_web_devi_key' AS column_name,
#     COUNT(DISTINCT int_web_devi_key) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'mcc' AS column_name,
#     COUNT(DISTINCT mcc) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'mcc_group' AS column_name,
#     COUNT(DISTINCT mcc_group) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'operator_department' AS column_name,
#     COUNT(DISTINCT operator_department) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'operator_name' AS column_name,
#     COUNT(DISTINCT operator_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'operator_nubmer' AS column_name,
#     COUNT(DISTINCT operator_nubmer) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'operator_position' AS column_name,
#     COUNT(DISTINCT operator_position) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'org_id' AS column_name,
#     COUNT(DISTINCT org_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'payee_account_type' AS column_name,
#     COUNT(DISTINCT payee_account_type) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'payee_bank_type' AS column_name,
#     COUNT(DISTINCT payee_bank_type) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'payee_bic' AS column_name,
#     COUNT(DISTINCT payee_bic) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'payee_currency' AS column_name,
#     COUNT(DISTINCT payee_currency) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'payee_name' AS column_name,
#     COUNT(DISTINCT payee_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'payee_ownership' AS column_name,
#     COUNT(DISTINCT payee_ownership) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'payee_user_id' AS column_name,
#     COUNT(DISTINCT payee_user_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'payer_bic' AS column_name,
#     COUNT(DISTINCT payer_bic) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'payer_name' AS column_name,
#     COUNT(DISTINCT payer_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'policy_action' AS column_name,
#     COUNT(DISTINCT policy_action) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'policy_action_aml' AS column_name,
#     COUNT(DISTINCT policy_action_aml) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'policy_action_fr' AS column_name,
#     COUNT(DISTINCT policy_action_fr) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'policy_rule_id' AS column_name,
#     COUNT(DISTINCT policy_rule_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'policy_rule_id_aml' AS column_name,
#     COUNT(DISTINCT policy_rule_id_aml) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'policy_rule_id_fr' AS column_name,
#     COUNT(DISTINCT policy_rule_id_fr) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'policy_rule_name' AS column_name,
#     COUNT(DISTINCT policy_rule_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'policy_rule_num_aml' AS column_name,
#     COUNT(DISTINCT policy_rule_num_aml) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'policy_rule_num_fr' AS column_name,
#     COUNT(DISTINCT policy_rule_num_fr) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_active_state' AS column_name,
#     COUNT(DISTINCT pos_active_state) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_auth_cap' AS column_name,
#     COUNT(DISTINCT pos_auth_cap) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_auth_entity' AS column_name,
#     COUNT(DISTINCT pos_auth_entity) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_auth_method' AS column_name,
#     COUNT(DISTINCT pos_auth_method) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_capture_cap' AS column_name,
#     COUNT(DISTINCT pos_capture_cap) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_card_presence' AS column_name,
#     COUNT(DISTINCT pos_card_presence) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_cardholder_presence' AS column_name,
#     COUNT(DISTINCT pos_cardholder_presence) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_data_input_cap' AS column_name,
#     COUNT(DISTINCT pos_data_input_cap) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_data_input_mode' AS column_name,
#     COUNT(DISTINCT pos_data_input_mode) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_data_out_cap' AS column_name,
#     COUNT(DISTINCT pos_data_out_cap) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_final_scoring' AS column_name,
#     COUNT(DISTINCT pos_final_scoring) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_merchant_scoring' AS column_name,
#     COUNT(DISTINCT pos_merchant_scoring) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_op_env' AS column_name,
#     COUNT(DISTINCT pos_op_env) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_partial_approval' AS column_name,
#     COUNT(DISTINCT pos_partial_approval) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_pin_cap_cap' AS column_name,
#     COUNT(DISTINCT pos_pin_cap_cap) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_pin_service_code' AS column_name,
#     COUNT(DISTINCT pos_pin_service_code) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_pin_service_result' AS column_name,
#     COUNT(DISTINCT pos_pin_service_result) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_purchase_amt_only' AS column_name,
#     COUNT(DISTINCT pos_purchase_amt_only) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_real_time_subst' AS column_name,
#     COUNT(DISTINCT pos_real_time_subst) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_term_out_cap' AS column_name,
#     COUNT(DISTINCT pos_term_out_cap) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'pos_type' AS column_name,
#     COUNT(DISTINCT pos_type) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'resolution' AS column_name,
#     COUNT(DISTINCT resolution) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'resolution_aml' AS column_name,
#     COUNT(DISTINCT resolution_aml) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'resolution_date' AS column_name,
#     COUNT(DISTINCT resolution_date) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'resolution_date_aml' AS column_name,
#     COUNT(DISTINCT resolution_date_aml) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'ter_code' AS column_name,
#     COUNT(DISTINCT ter_code) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'tra_cln_def' AS column_name,
#     COUNT(DISTINCT tra_cln_def) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'tra_cln_typ' AS column_name,
#     COUNT(DISTINCT tra_cln_typ) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'tra_tra_amo_cur' AS column_name,
#     COUNT(DISTINCT tra_tra_amo_cur) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'tra_tra_oth_id' AS column_name,
#     COUNT(DISTINCT tra_tra_oth_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'tra_tra_own_id' AS column_name,
#     COUNT(DISTINCT tra_tra_own_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'trx_atm_id' AS column_name,
#     COUNT(DISTINCT trx_atm_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'trx_terminal_id' AS column_name,
#     COUNT(DISTINCT trx_terminal_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'unified_id' AS column_name,
#     COUNT(DISTINCT unified_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_birthdate' AS column_name,
#     COUNT(DISTINCT user_birthdate) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_category' AS column_name,
#     COUNT(DISTINCT user_category) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_doc_number' AS column_name,
#     COUNT(DISTINCT user_doc_number) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_doc_type' AS column_name,
#     COUNT(DISTINCT user_doc_type) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_first_name' AS column_name,
#     COUNT(DISTINCT user_first_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_id' AS column_name,
#     COUNT(DISTINCT user_id) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_last_name' AS column_name,
#     COUNT(DISTINCT user_last_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_name' AS column_name,
#     COUNT(DISTINCT user_name) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_patronymic' AS column_name,
#     COUNT(DISTINCT user_patronymic) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_segment' AS column_name,
#     COUNT(DISTINCT user_segment) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'user_type' AS column_name,
#     COUNT(DISTINCT user_type) AS unique_count
#   FROM anti_frod
#   UNION ALL
#   SELECT
#     'usr_ip_cur_add' AS column_name,
#     COUNT(DISTINCT usr_ip_cur_add) AS unique_count
#   FROM anti_frod

# %%
Time_3 = (
"table_name: Time_3",
"main_dttm_col: null",
"description: null",
"default_endpoint: null",
"offset: 0",
"cache_timeout: null",
"catalog: postgres",
"schema: public",
f"sql: {(final_query_time_3)} ",
"params: null",
"template_params: null",
"filter_select_enabled: true",
"fetch_values_predicate: null",
"extra: null",
"normalize_columns: false",
"always_filter_main_dttm: false",
"uuid: 094fc1fa-42e9-427d-a9a1-0fa661fb5fa8",
"metrics:",
"- metric_name: count",
"  verbose_name: COUNT(*)",
"  metric_type: count",
"  expression: COUNT(*)",
"  description: null",
"  d3format: null",
"  currency: null",
"  extra: null",
"  warning_text: null",
"columns:",
"- column_name: unique_count",
"  verbose_name: null",
"  is_dttm: false",
"  is_active: true",
"  type: LONGINTEGER",
"  advanced_data_type: null",
"  groupby: true",
"  filterable: true",
"  expression: null",
"  description: null",
"  python_date_format: null",
"  extra: null",
"- column_name: column_name",
"  verbose_name: null",
"  is_dttm: false",
"  is_active: true",
"  type: STRING",
"  advanced_data_type: null",
"  groupby: true",
"  filterable: true",
"  expression: null",
"  description: null",
"  python_date_format: null",
"  extra: null",
"version: 1.0.0",
"database_uuid: 2f651e35-38e7-4b9b-a47e-87996c769118"
)

# %% [markdown]
# Time_4

# %%
columns =  df.columns.tolist()


column_list = "', '".join(columns)
final_query_time_4=(
    "SELECT\r\n"
    "   column_name AS \"Column_Name\",\r\n"
    "   data_type AS \"Data_Type\"\r\n"
    "   FROM\r\n"
    "       information_schema.columns\r\n"
    f"   WHERE table_name = '{table_name}'\r\n"
    f"   AND column_name IN ('{column_list}')"
)
final_query_time_4
# Out:
# 'SELECT\r\n   column_name AS "Column_Name",\r\n   data_type AS "Data_Type"\r\n   FROM\r\n       information_schema.columns\r\n   WHERE table_name = \'anti_frod\'\r\n   AND column_name IN (\'atm_acquiring_country\', \'atm_acquiring_icc\', \'atm_branch\', \'atm_card_entry_mode\', \'atm_cardless\', \'atm_cash_in\', \'atm_cash_in_acc\', \'atm_cash_in_pay\', \'atm_city\', \'atm_class\', \'atm_continent\', \'atm_country\', \'atm_cvv_check\', \'atm_exchange\', \'atm_forwarding_icc\', \'atm_is_fi_owner\', \'atm_merchant_id\', \'atm_merchant_name\', \'atm_owner_fi_name\', \'atm_pin_check\', \'atm_pin_entry_mode\', \'atm_receiving_icc\', \'atm_region\', \'atm_retailer_name\', \'atm_usr_num_hit\', \'atm_virt\', \'atm_zip\', \'branch_branch\', \'branch_host\', \'branch_office\', \'branch_operator_id\', \'branch_tercode\', \'card_balance\', \'card_balance_currency\', \'card_bin\', \'card_category\', \'card_contract_currency\', \'card_day_limit\', \'card_day_limit_currency\', \'card_days_since_issue\', \'card_expire_date\', \'card_issue_date\', \'card_issuer_country\', \'card_issuer_id\', \'card_number\', \'card_product\', \'card_system\', \'card_type\', \'cardholder_amount\', \'cardholder_currency\', \'channel\', \'client_trx_id\', \'conv_rate\', \'device_tz\', \'devi_src_mob_har\', \'devi_src_mob_osid\', \'ec_card_validarion_res\', \'ec_cvv2_data\', \'event_time\', \'event_type\', \'evt_act\', \'ext_amount_rub\', \'ext_branch_region\', \'ext_device_hash\', \'ext_evt_des\', \'ext_issuer_bank_name\', \'ext_mtid\', \'ext_operation_category\', \'ext_operation_id\', \'ext_operation_type\', \'ext_payee_acc\', \'ext_payee_bic\', \'ext_payee_card_num\', \'ext_payee_inn\', \'ext_user_phone\', \'ext_payer_inn\', \'ext_resp_code\', \'ext_user_bic\', \'ext_user_inn\', \'ext_usr_log\', \'ext_usr_tax\', \'fraud_type\', \'fraud_type_aml\', \'geoip_city\', \'geoip_country\', \'geoip_provider\', \'geoip_region\', \'ip_classa\', \'ip_classb\', \'ip_classc\', \'int_web_devi_key\', \'ip_mv_too_fast\', \'mcc\', \'mcc_group\', \'operator_department\', \'operator_name\', \'operator_nubmer\', \'operator_position\', \'org_id\', \'payee_account_type\', \'payee_amount\', \'payee_bank_type\', \'payee_bic\', \'payee_currency\', \'payee_name\', \'payee_ownership\', \'payee_rate\', \'payee_user_id\', \'payer_bic\', \'payer_name\', \'policy_action\', \'policy_action_aml\', \'policy_action_fr\', \'policy_rule_id\', \'policy_rule_id_aml\', \'policy_rule_id_fr\', \'policy_rule_name\', \'policy_rule_num_aml\', \'policy_rule_num_fr\', \'pos_active_state\', \'pos_auth_cap\', \'pos_auth_entity\', \'pos_auth_method\', \'pos_capture_cap\', \'pos_card_presence\', \'pos_cardholder_presence\', \'pos_data_input_cap\', \'pos_data_input_mode\', \'pos_data_out_cap\', \'pos_final_scoring\', \'pos_merchant_scoring\', \'pos_op_env\', \'pos_partial_approval\', \'pos_pin_cap_cap\', \'pos_pin_service_code\', \'pos_pin_service_result\', \'pos_purchase_amt_only\', \'pos_real_time_subst\', \'pos_term_out_cap\', \'pos_type\', \'repl_amount\', \'resolution\', \'resolution_aml\', \'resolution_date\', \'resolution_date_aml\', \'risk_score_aml_final\', \'risk_score_final\', \'risk_score_payee_final\', \'ter_code\', \'tra_cln_def\', \'tra_cln_typ\', \'tra_tra_amo_amo\', \'tra_tra_amo_cur\', \'tra_tra_oth_id\', \'tra_tra_own_id\', \'trx_atm_id\', \'trx_terminal_id\', \'u_atm_day_f_hit\', \'u_atm_day_l_hit\', \'u_day_sin_ema_cha\', \'u_day_sin_f_hit\', \'u_day_sin_pwd_cha\', \'u_day_sin_tel_cha\', \'u_devprn_day_f_hit\', \'u_hour_sin_f_hit\', \'u_ip_day_sin_f_hit\', \'u_ip_diff_from_p\', \'u_ipb_day_sin_f_hit\', \'u_ipc_day_sin_f_hit\', \'u_isp_day_sin_f_hit\', \'u_mobdev_day_sin_f_hit\', \'u_mobdev_day_sin_l_hit\', \'u_mobisp_day_sin_f_hit\', \'u_mobmac_day_sin_f_hit\', \'u_p_day_sin_f_hit\', \'u_sim_day_sin_f_hit\', \'u_webdev_day_sin_f_hit\', \'u_webdev_day_sin_l_hit\', \'unified_id\', \'user_birthdate\', \'user_category\', \'user_doc_number\', \'user_doc_type\', \'user_first_name\', \'user_id\', \' ...

# %%
Time_4 = (
"table_name: Time_4",
"main_dttm_col: null",
"description: null",
"default_endpoint: null",
"offset: 0",
"cache_timeout: null",
"catalog: postgres",
"schema: public",
f"sql: {(final_query_time_4)} ",
"params: null",
"template_params: null",
"filter_select_enabled: true",
"fetch_values_predicate: null",
"extra: null",
"normalize_columns: false",
"always_filter_main_dttm: false",
"uuid: 763ef388-5be4-46bb-b7e7-f0fb3254eeff",
"metrics:",
"- metric_name: count",
"  verbose_name: COUNT(*)",
"  metric_type: count",
"  expression: COUNT(*)",
"  description: null",
"  d3format: null",
"  currency: null",
"  extra: null",
"  warning_text: null",
"columns:",
"- column_name: Column_Name",
"  verbose_name: null",
"  is_dttm: false",
"  is_active: true",
"  type: STRING",
"  advanced_data_type: null",
"  groupby: true",
"  filterable: true",
"  expression: null",
"  description: null",
"  python_date_format: null",
"  extra: null",
"- column_name: Data_Type",
"  verbose_name: null",
"  is_dttm: false",
"  is_active: true",
"  type: STRING",
"  advanced_data_type: null",
"  groupby: true",
"  filterable: true",
"  expression: null",
"  description: null",
"  python_date_format: null",
"  extra: null",
"version: 1.0.0",
"database_uuid: 2f651e35-38e7-4b9b-a47e-87996c769118"
)

# %% [markdown]
# Time_5

# %%
columns =  df.columns.tolist()


column_list = "', '".join(columns)
final_query_time_5 = (
    "SELECT\r\n"
    "    COUNT(*) FILTER (WHERE data_type ILIKE 'character varying' OR data_type ILIKE 'text') AS text_column_count,\r\n"
    "    COUNT(*) FILTER (WHERE data_type ILIKE 'integer' OR data_type ILIKE 'numeric' OR data_type ILIKE 'double precision' OR data_type ILIKE 'real') AS numeric_column_count,\r\n"
    "    COUNT(*) FILTER (WHERE data_type ILIKE 'TIMESTAMP' OR data_type ILIKE 'time' OR data_type ILIKE 'date') AS time_column_count\r\n"
    "   FROM information_schema.columns\r\n"
    f"   WHERE table_name = '{table_name}'\r\n"
    f"   AND column_name IN ('{column_list}')"
)
final_query_time_5
# Out:
# "SELECT\r\n    COUNT(*) FILTER (WHERE data_type ILIKE 'character varying' OR data_type ILIKE 'text') AS text_column_count,\r\n    COUNT(*) FILTER (WHERE data_type ILIKE 'integer' OR data_type ILIKE 'numeric' OR data_type ILIKE 'double precision' OR data_type ILIKE 'real') AS numeric_column_count,\r\n    COUNT(*) FILTER (WHERE data_type ILIKE 'TIMESTAMP' OR data_type ILIKE 'time' OR data_type ILIKE 'date') AS time_column_count\r\n   FROM information_schema.columns\r\n   WHERE table_name = 'anti_frod'\r\n   AND column_name IN ('atm_acquiring_country', 'atm_acquiring_icc', 'atm_branch', 'atm_card_entry_mode', 'atm_cardless', 'atm_cash_in', 'atm_cash_in_acc', 'atm_cash_in_pay', 'atm_city', 'atm_class', 'atm_continent', 'atm_country', 'atm_cvv_check', 'atm_exchange', 'atm_forwarding_icc', 'atm_is_fi_owner', 'atm_merchant_id', 'atm_merchant_name', 'atm_owner_fi_name', 'atm_pin_check', 'atm_pin_entry_mode', 'atm_receiving_icc', 'atm_region', 'atm_retailer_name', 'atm_usr_num_hit', 'atm_virt', 'atm_zip', 'branch_branch', 'branch_host', 'branch_office', 'branch_operator_id', 'branch_tercode', 'card_balance', 'card_balance_currency', 'card_bin', 'card_category', 'card_contract_currency', 'card_day_limit', 'card_day_limit_currency', 'card_days_since_issue', 'card_expire_date', 'card_issue_date', 'card_issuer_country', 'card_issuer_id', 'card_number', 'card_product', 'card_system', 'card_type', 'cardholder_amount', 'cardholder_currency', 'channel', 'client_trx_id', 'conv_rate', 'device_tz', 'devi_src_mob_har', 'devi_src_mob_osid', 'ec_card_validarion_res', 'ec_cvv2_data', 'event_time', 'event_type', 'evt_act', 'ext_amount_rub', 'ext_branch_region', 'ext_device_hash', 'ext_evt_des', 'ext_issuer_bank_name', 'ext_mtid', 'ext_operation_category', 'ext_operation_id', 'ext_operation_type', 'ext_payee_acc', 'ext_payee_bic', 'ext_payee_card_num', 'ext_payee_inn', 'ext_user_phone', 'ext_payer_inn', 'ext_resp_code', 'ext_user_bic', 'ext_user_inn', 'ext_usr_log', 'ext_usr_tax', 'fraud_type', 'fraud_type_aml', 'geoip_city', 'geoip_country', 'geoip_provider', 'geoip_region', 'ip_classa', 'ip_classb', 'ip_classc', 'int_web_devi_key', 'ip_mv_too_fast', 'mcc', 'mcc_group', 'operator_department', 'operator_name', 'operator_nubmer', 'operator_position', 'org_id', 'payee_account_type', 'payee_amount', 'payee_bank_type', 'payee_bic', 'payee_currency', 'payee_name', 'payee_ownership', 'payee_rate', 'payee_user_id', 'payer_bic', 'payer_name', 'policy_action', 'policy_action_aml', 'policy_action_fr', 'policy_rule_id', 'policy_rule_id_aml', 'policy_rule_id_fr', 'policy_rule_name', 'policy_rule_num_aml', 'policy_rule_num_fr', 'pos_active_state', 'pos_auth_cap', 'pos_auth_entity', 'pos_auth_method', 'pos_capture_cap', 'pos_card_presence', 'pos_cardholder_presence', 'pos_data_input_cap', 'pos_data_input_mode', 'pos_data_out_cap', 'pos_final_scoring', 'pos_merchant_scoring', 'pos_op_env', 'pos_partial_approval', 'pos_pin_cap_cap', 'pos_pin_service_code', 'pos_pin_service_result', 'pos_purchase_amt_only', 'pos_real_time_subst', 'pos_term_out_cap', 'pos_type', 'repl_amount', 'resolution', 'resolution_aml', 'resolution_date', 'resolution_date_aml', 'risk_score_aml_final', 'risk_score_final', 'risk_score_payee_final', 'ter_code', 'tra_cln_def', 'tra_cln_typ', 'tra_tra_amo_amo', 'tra_tra_amo_cur', 'tra_tra_oth_id', 'tra_tra_own_id', 'trx_atm_id', 'trx_terminal_id', 'u_atm_day_f_hit', 'u_atm_day_l_hit', 'u_day_sin_ema_cha', 'u_day_sin_f_hit', 'u_day_sin_pwd_cha', 'u_day_sin_tel_cha', 'u_devprn_day_f_hit', 'u_hour_sin_f_hit', 'u_ip_day_sin_f_hit', 'u_ip_diff_from_p', 'u_ipb_day_sin_f_hit', 'u_ipc_day_sin_f_hit', 'u_isp_day_sin_f_hit', 'u_mobdev_day_sin_f_hit', 'u_mobdev_day_sin_l_hit', 'u_mobisp_day_sin_f_hit', 'u_mobmac_day_sin_f_hit', 'u_p_day_sin_f_hit', 'u_sim_day_sin_f_hit', 'u_webdev_day_sin_f_hit', 'u_webdev_day_sin_l_hit', 'unified_id', 'user_birthdate', 'user_category', 'user_doc_number', 'user_doc_type', 'user_first_name', 'user_id', 'user_last_name', 'user_name' ...

# %%
Time_5 = (
"table_name: Time_5",
"main_dttm_col: null",
"description: null",
"default_endpoint: null",
"offset: 0",
"cache_timeout: null",
"catalog: postgres",
"schema: public",
f"sql: {repr(final_query_time_5)} ",
"params: null",
"template_params: null",
"filter_select_enabled: true",
"fetch_values_predicate: null",
"extra: null",
"normalize_columns: false",
"always_filter_main_dttm: false",
"uuid: d661cc21-5919-4136-aa9d-cec6f3886047",
"metrics:",
"- metric_name: count",
"  verbose_name: COUNT(*)",
"  metric_type: count",
"  expression: COUNT(*)",
"  description: null",
"  d3format: null",
"  currency: null",
"  extra: null",
"  warning_text: null",
"columns:",
"- column_name: numeric_column_count",
"  verbose_name: null",
"  is_dttm: false",
"  is_active: true",
"  type: LONGINTEGER",
"  advanced_data_type: null",
"  groupby: true",
"  filterable: true",
"  expression: null",
"  description: null",
"  python_date_format: null",
"  extra: null",
"- column_name: time_column_count",
"  verbose_name: null",
"  is_dttm: false",
"  is_active: true",
"  type: LONGINTEGER",
"  advanced_data_type: null",
"  groupby: true",
"  filterable: true",
"  expression: null",
"  description: null",
"  python_date_format: null",
"  extra: null",
"- column_name: text_column_count",
"  verbose_name: null",
"  is_dttm: false",
"  is_active: true",
"  type: LONGINTEGER",
"  advanced_data_type: null",
"  groupby: true",
"  filterable: true",
"  expression: null",
"  description: null",
"  python_date_format: null",
"  extra: null",
"version: 1.0.0",
"database_uuid: 2f651e35-38e7-4b9b-a47e-87996c769118"
)

# %% [markdown]
# Time_6

# %%
import io
from minio import Minio
from minio.error import S3Error

# Конфигурация MinIO
endpoint = "127.0.0.1:32020"  # Адрес MinIO сервера
access_key = "qxiYSHv8QP4QE0Ctk0fI"  # Ваш Access Key
secret_key = "34w2smESi4yNjxS9ga1ibJqhXGpdSerTsSnvkQHH"
bucket_name = "dashbord-paket"  # Название бакета

# Инициализируем клиента MinIO
client = Minio(
    endpoint,
    access_key=access_key,
    secret_key=secret_key,
    secure=False  # Установите True, если используется HTTPS
)

def upload_to_minio(bucket, file_path, content):
    """
    Загрузить содержимое файла в MinIO.

    :param bucket: Название бакета
    :param file_path: Путь к файлу внутри бакета
    :param content: Содержимое файла для записи (строка или bytes)
    """
    try:
        # Убедитесь, что бакет существует
        if not client.bucket_exists(bucket):
            client.make_bucket(bucket)

        # Преобразуем содержимое в поток
        if isinstance(content, str):
            content = content.encode('utf-8')  # Кодируем строку в bytes
        data_stream = io.BytesIO(content)  # Создаём поток

        # Загружаем данные в MinIO
        client.put_object(
            bucket,
            file_path,
            data=data_stream,
            length=len(content),
            content_type="text/yaml"
        )
        print(f"Файл '{file_path}' успешно загружен в бакет '{bucket}'.")
    except S3Error as err:
        print(f"Ошибка загрузки в MinIO: {err}")

# Список файлов для записи
time_files = {
    "dashboard_export_time/datasets/PostgreSQL/Time_5.yaml": '\n'.join(Time_5),
    "dashboard_export_time/datasets/PostgreSQL/Time_4.yaml": '\n'.join(Time_4),
    "dashboard_export_time/datasets/PostgreSQL/Time_3.yaml": '\n'.join(Time_3),
    "dashboard_export_time/datasets/PostgreSQL/Time_2.yaml": '\n'.join(Time_2),
    "dashboard_export_time/datasets/PostgreSQL/Time_1.yaml": '\n'.join(Time_1),
}

# Загрузка файлов в MinIO
for file_path, content in time_files.items():
    upload_to_minio(bucket_name, file_path, content.encode('utf-8'))
# Out:
# Файл 'dashboard_export_time/datasets/PostgreSQL/Time_5.yaml' успешно загружен в бакет 'dashbord-paket'.
# Файл 'dashboard_export_time/datasets/PostgreSQL/Time_4.yaml' успешно загружен в бакет 'dashbord-paket'.
# Файл 'dashboard_export_time/datasets/PostgreSQL/Time_3.yaml' успешно загружен в бакет 'dashbord-paket'.
# Файл 'dashboard_export_time/datasets/PostgreSQL/Time_2.yaml' успешно загружен в бакет 'dashbord-paket'.
# Файл 'dashboard_export_time/datasets/PostgreSQL/Time_1.yaml' успешно загружен в бакет 'dashbord-paket'.

# %%
import io
import zipfile
from minio import Minio
from minio.error import S3Error

# Конфигурация MinIO
endpoint = "127.0.0.1:32020"  # Адрес MinIO сервера
access_key = "qxiYSHv8QP4QE0Ctk0fI"  # Ваш Access Key
secret_key = "34w2smESi4yNjxS9ga1ibJqhXGpdSerTsSnvkQHH"  # Ваш Secret Key
bucket_name = "dashbord-paket"  # Название бакета
folder_prefix = "innstd_time_no_time_6/"  # Префикс папки
output_zip_name = "innstd_time_no_time_6.zip"  # Название архива

# Инициализация клиента MinIO
client = Minio(
    endpoint,
    access_key=access_key,
    secret_key=secret_key,
    secure=False  # Установите True, если используется HTTPS
)

def zip_folder_from_minio(bucket, folder_prefix, output_zip_name):
    """
    Сжать всю папку в архив и сохранить её в MinIO.
    
    :param bucket: Название бакета
    :param folder_prefix: Префикс папки в бакете (например, 'dashboard_export_time/')
    :param output_zip_name: Название ZIP файла для сохранения в MinIO
    """
    try:
        # Список объектов в указанной "папке"
        objects = client.list_objects(bucket, prefix=folder_prefix, recursive=True)
        zip_stream = io.BytesIO()

        # Создаём архив ZIP в памяти
        with zipfile.ZipFile(zip_stream, 'w', zipfile.ZIP_DEFLATED) as zipf:
            for obj in objects:
                # Скачиваем объект в память
                obj_data = client.get_object(bucket, obj.object_name)
                file_data = obj_data.read()

                # Добавляем объект в ZIP архив с сохранением структуры
                relative_path = obj.object_name  # Сохраняем полный путь в архиве
                zipf.writestr(relative_path, file_data)
                obj_data.close()

        # Перемещаем указатель в начало потока
        zip_stream.seek(0)

        # Сохраняем ZIP архив обратно в MinIO
        client.put_object(
            bucket,
            output_zip_name,
            data=zip_stream,
            length=len(zip_stream.getvalue()),
            content_type="application/zip"
        )
        print(f"Архив '{output_zip_name}' успешно создан в бакете '{bucket}'.")
    except S3Error as err:
        print(f"Ошибка работы с MinIO: {err}")

# Пример вызова функции
zip_folder_from_minio(bucket_name, folder_prefix, output_zip_name)
# Out:
# Архив 'innstd_time_no_time_6.zip' успешно создан в бакете 'dashbord-paket'.

# %%
import requests
import io
from minio import Minio

# Конфигурация Superset
SUPERSET_PROTOCOL = "http"
SUPERSET_HOST = "localhost:8088"
SUPERSET_USERNAME = "admin"
SUPERSET_PASSWORD = "admin"

# Конфигурация MinIO
class Importer:
    def __init__(self):
        self.session = requests.Session()
        self.get_superset_access_token()
        self.get_csrf_token()

    def get_superset_access_token(self):
        # URL для получения токена
        endpoint = "/api/v1/security/login"
        url = f"{SUPERSET_PROTOCOL}://{SUPERSET_HOST}{endpoint}"
        
        # Данные для аутентификации
        credentials = {
            "username": SUPERSET_USERNAME,
            "password": SUPERSET_PASSWORD,
            "provider": "db",
            "refresh": True
        }

        # Запрос на получение токена
        response = self.session.post(url, json=credentials)
        
        if response.status_code == 200:
            access_token = response.json().get('access_token')
            self.session.headers.update({
                'Authorization': f'Bearer {access_token}'
            })
        else:
            print("Ошибка при получении токена:", response.status_code, response.text)
            raise Exception(f"Ошибка получения токена: {response.status_code}")

    def get_csrf_token(self):
        # URL для получения CSRF-токена
        endpoint = "/api/v1/security/csrf_token/"
        url = f"{SUPERSET_PROTOCOL}://{SUPERSET_HOST}{endpoint}"
        
        # Запрос на получение CSRF-токена
        response = self.session.get(url)
        if response.status_code == 200:
            csrf_token = response.json().get("result")
            self.session.headers.update({
                'X-CSRFToken': csrf_token
            })
        else:
            print("Ошибка при получении CSRF токена:", response.status_code, response.text)
            raise Exception(f"Ошибка получения CSRF токена: {response.status_code}")

    def import_dashboard(self, zip_data_stream):
        # URL для импорта дашборда
        endpoint = "/api/v1/dashboard/import/"
        url = f"{SUPERSET_PROTOCOL}://{SUPERSET_HOST}{endpoint}"
        
        # Формируем данные для отправки
        files = {'formData': ("innstd_time_no_time_6.zip", zip_data_stream, 'application/zip')}
        payload = {
            'overwrite': 'true'
        }

        # Отправляем запрос на импорт дашборда
        response = self.session.post(url, files=files, data=payload)

        if response.status_code == 200:
            print("Дашборд успешно импортирован.")
        else:
            print("Ошибка при импорте дашборда:", response.status_code, response.text)


def get_file_from_minio(bucket, file_name):
    """
    Загружает файл из MinIO и возвращает его как поток байтов.
    
    :param bucket: Название бакета
    :param file_name: Имя файла в бакете
    :return: Поток данных (BytesIO)
    """
    try:
        # Загружаем файл в память
        response = client.get_object(bucket, file_name)
        file_data = io.BytesIO(response.read())
        response.close()
        response.release_conn()
        print(f"Файл '{file_name}' успешно загружен из MinIO.")
        return file_data
    except S3Error as err:
        print(f"Ошибка при работе с MinIO: {err}")
        raise


if __name__ == "__main__":
    try:
        # Получаем файл из MinIO
        zip_data_stream = get_file_from_minio(bucket_name, output_zip_name)

        # Импортируем дашборд
        importer = Importer()
        importer.import_dashboard(zip_data_stream)
    except Exception as e:
        print(f"Ошибка выполнения: {e}")
# Out:
# Файл 'innstd_time_no_time_6.zip' успешно загружен из MinIO.
# Дашборд успешно импортирован.
